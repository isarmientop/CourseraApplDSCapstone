# %%
# importar librerias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Datos
models = ['LR', 'SVM', 'Decision Tree', 'K Nearest']
accuracies = [0.8462429, 0.848214, 0.901785, 0.848214]

# %%
# Crear el DataFrame
df = pd.DataFrame({
    'Model': models,
    'Accuracy': accuracies
})

# %%
# Mostrar el DataFrame
print(df)
# Out:
#            Model  Accuracy
# 0             LR  0.846243
# 1            SVM  0.848214
# 2  Decision Tree  0.901785
# 3      K Nearest  0.848214

# %%
# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.title('Model Accuracy Comparison')
sns.barplot(x='Model', y='Accuracy', data=df, palette='viridis')
# Out:
# <ipython-input-8-2f661dba80f0>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Model', y='Accuracy', data=df, palette='viridis')
# <Axes: title={'center': 'Model Accuracy Comparison'}, xlabel='Model', ylabel='Accuracy'>

# %%
# Añadir títulos y etiquetas
plt.title('Model Accuracy Comparison')
plt.xlabel('Model')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# Mostrar el gráfico
plt.show()
